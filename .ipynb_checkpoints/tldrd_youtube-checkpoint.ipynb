# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import TextFormatter

# %%
formatter = TextFormatter()
transcript = YouTubeTranscriptApi.get_transcript("8a1yTN2kFNw")
text = formatter.format_transcript(transcript)

# %%
# Out:
# WEBVTT
#
# 00:00:00.030 --> 00:00:01.800
# on this episode of cyber weapons lab
#
# 00:00:01.800 --> 00:00:03.179
# we're gonna learn a six step framework
#
# 00:00:03.179 --> 00:00:06.400
# in order to pen test like a pro
#
# 00:00:06.400 --> 00:00:16.400
# [Music]
#
# 00:00:16.400 --> 00:00:18.480
# penetration testing is a science and
#
# 00:00:18.480 --> 00:00:20.310
# just like any other science a consistent
#
# 00:00:20.310 --> 00:00:21.930
# methodology has to be applied in order
#
# 00:00:21.930 --> 00:00:24.480
# to achieve good results the six steps
#
# 00:00:24.480 --> 00:00:25.650
# we're going to learn today will allow
#
# 00:00:25.650 --> 00:00:27.119
# you to find and exploit vulnerabilities
#
# 00:00:27.119 --> 00:00:28.590
# much more easily and much more
#
# 00:00:28.590 --> 00:00:30.390
# efficiently and they'll also allow you
#
# 00:00:30.390 --> 00:00:31.920
# to learn from your failures much easier
#
# 00:00:31.920 --> 00:00:34.020
# as well the six steps that we're going
#
# 00:00:34.020 --> 00:00:35.719
# to cover today are pre-engagement
#
# 00:00:35.719 --> 00:00:38.600
# reconnaissance vulnerability assessment
#
# 00:00:38.600 --> 00:00:41.219
# exploitation post exploitation and
#
# 00:00:41.219 --> 00:00:43.559
# reporting the engagement is the phase
#
# 00:00:43.559 --> 00:00:44.879
# where we determine the type of device
#
# 00:00:44.879 --> 00:00:46.559
# what we're interested in exploiting a
#
# 00:00:46.559 --> 00:00:49.050
# personal computer a web server or an
#
# 00:00:49.050 --> 00:00:50.489
# Internet of Things device they're gonna
#
# 00:00:50.489 --> 00:00:52.199
# have a drastic impact on all of the
#
# 00:00:52.199 --> 00:00:55.020
# following steps it's also important in
#
# 00:00:55.020 --> 00:00:56.160
# this phase to consider the legal
#
# 00:00:56.160 --> 00:00:58.050
# ramifications of performing an
#
# 00:00:58.050 --> 00:00:59.760
# exploitation on that type of device as
#
# 00:00:59.760 --> 00:01:01.590
# this is the point of no-return the
#
# 00:01:01.590 --> 00:01:03.149
# reconnaissance phase is where we use
#
# 00:01:03.149 --> 00:01:05.010
# tools such as nmap to scan local
#
# 00:01:05.010 --> 00:01:07.200
# networks or tools like show Dan to scan
#
# 00:01:07.200 --> 00:01:09.000
# the entire Internet to define devices
#
# 00:01:09.000 --> 00:01:10.260
# that are potentially vulnerable to
#
# 00:01:10.260 --> 00:01:12.030
# exploitation phase three is the
#
# 00:01:12.030 --> 00:01:14.070
# vulnerability assessment phase this is
#
# 00:01:14.070 --> 00:01:15.210
# where we narrow down the number of
#
# 00:01:15.210 --> 00:01:16.850
# devices that we gathered in Phase two
#
# 00:01:16.850 --> 00:01:19.080
# reconnaissance two devices which are
#
# 00:01:19.080 --> 00:01:20.369
# known to be vulnerable to known
#
# 00:01:20.369 --> 00:01:22.580
# exploitation for this we can use
#
# 00:01:22.580 --> 00:01:24.780
# pre-built tools or we can use our
#
# 00:01:24.780 --> 00:01:27.000
# knowledge of outdated versions of
#
# 00:01:27.000 --> 00:01:29.070
# software to find devices which are known
#
# 00:01:29.070 --> 00:01:32.040
# to be vulnerable stage four exploitation
#
# 00:01:32.040 --> 00:01:34.229
# is arguably the most exciting phase of a
#
# 00:01:34.229 --> 00:01:36.270
# penetration test this is where we use
#
# 00:01:36.270 --> 00:01:37.710
# all the intelligence that we've gathered
#
# 00:01:37.710 --> 00:01:39.570
# in the previous three steps and apply it
#
# 00:01:39.570 --> 00:01:42.299
# to exploit our targeted device now this
#
# 00:01:42.299 --> 00:01:43.649
# can vary widely based on the type of
#
# 00:01:43.649 --> 00:01:45.149
# exploitation but today we're going to be
#
# 00:01:45.149 --> 00:01:46.920
# showing command injection Stage five
#
# 00:01:46.920 --> 00:01:49.530
# post exploitation is only possible after
#
# 00:01:49.530 --> 00:01:51.810
# a successful exploitation is completed
#
# 00:01:51.810 --> 00:01:54.420
# this is where we use our newfound access
#
# 00:01:54.420 --> 00:01:55.829
# to the device in order to raise our
#
# 00:01:55.829 --> 00:01:57.780
# privileges or gain permanent access to
#
# 00:01:57.780 --> 00:01:59.520
# that device the final stage of a
#
# 00:01:59.520 --> 00:02:01.590
# penetration test is reporting this is
#
# 00:02:01.590 --> 00:02:02.759
# where we gather all the knowledge that
#
# 00:02:02.759 --> 00:02:04.380
# we gain throughout the penetration test
#
# 00:02:04.380 --> 00:02:06.299
# organize it and publish it so other
#
# 00:02:06.299 --> 00:02:07.380
# people can be aware of this
#
# 00:02:07.380 --> 00:02:09.569
# vulnerability on this episode of cyber
#
# 00:02:09.569 --> 00:02:11.819
# weapons lab we're going to be targeting
#
# 00:02:11.819 --> 00:02:13.319
# a web server on our low
#
# 00:02:13.319 --> 00:02:15.420
# at work we're gonna be using nmap for
#
# 00:02:15.420 --> 00:02:17.219
# reconnaissance we're going to be using
#
# 00:02:17.219 --> 00:02:18.870
# Nessus for vulnerability assessment
#
# 00:02:18.870 --> 00:02:20.370
# we're gonna be using command injection
#
# 00:02:20.370 --> 00:02:22.799
# in order to exploit the device and we're
#
# 00:02:22.799 --> 00:02:24.269
# going to using posting them in order to
#
# 00:02:24.269 --> 00:02:26.639
# elevate our privileges on that device if
#
# 00:02:26.639 --> 00:02:28.859
# you have any problems of this tutorial
#
# 00:02:28.859 --> 00:02:30.000
# check out the article link in the
#
# 00:02:30.000 --> 00:02:32.310
# description all you need to follow this
#
# 00:02:32.310 --> 00:02:33.750
# tutorial is a computer to work with
#
# 00:02:33.750 --> 00:02:35.849
# let's get started so for the
#
# 00:02:35.849 --> 00:02:37.049
# reconnaissance stage we're just gonna
#
# 00:02:37.049 --> 00:02:39.750
# use a simple nmap scan and we've covered
#
# 00:02:39.750 --> 00:02:41.430
# nmap before on wondering how to and you
#
# 00:02:41.430 --> 00:02:43.079
# can check out the our tutorials on
#
# 00:02:43.079 --> 00:02:46.290
# wonder how to know by calm but I'm just
#
# 00:02:46.290 --> 00:02:47.760
# gonna show you a real quick one liner
#
# 00:02:47.760 --> 00:02:49.530
# that you can use to see if there's any
#
# 00:02:49.530 --> 00:02:51.930
# open port ATS on your local network so
#
# 00:02:51.930 --> 00:02:53.430
# to do that you just have to type in nmap
#
# 00:02:53.430 --> 00:02:56.459
# and then s capital v for service scan
#
# 00:02:56.459 --> 00:02:59.069
# and then you're just gonna select the
#
# 00:02:59.069 --> 00:03:01.199
# range of IPs that you want to scan
#
# 00:03:01.199 --> 00:03:06.810
# somebody 192.168.1.1 and we're gonna
#
# 00:03:06.810 --> 00:03:09.260
# specify our subnet mask with slash 24
#
# 00:03:09.260 --> 00:03:13.579
# then i'm going to specify port 80 and
#
# 00:03:13.579 --> 00:03:15.989
# i'm gonna go ahead and let that run it's
#
# 00:03:15.989 --> 00:03:17.250
# gonna take a couple seconds because it's
#
# 00:03:17.250 --> 00:03:21.180
# not a huge scan and after a couple
#
# 00:03:21.180 --> 00:03:23.549
# seconds we can see all the devices which
#
# 00:03:23.549 --> 00:03:25.109
# are attached to our local network and
#
# 00:03:25.109 --> 00:03:27.720
# whether it's open closed or filtered so
#
# 00:03:27.720 --> 00:03:29.790
# if it's open that means that port that
#
# 00:03:29.790 --> 00:03:33.329
# port 80 is open to use if it's closed
#
# 00:03:33.329 --> 00:03:34.949
# that means obviously we can't use port
#
# 00:03:34.949 --> 00:03:36.989
# 80 and then filtered means it may or may
#
# 00:03:36.989 --> 00:03:39.239
# not be open but we can't connect to it
#
# 00:03:39.239 --> 00:03:40.650
# usually port 80 s aren't filtered that's
#
# 00:03:40.650 --> 00:03:43.139
# you do something with SSH or other TCP
#
# 00:03:43.139 --> 00:03:44.819
# ports but today we're gonna be
#
# 00:03:44.819 --> 00:03:49.739
# interested in one 92168 1.1 4 6 and we
#
# 00:03:49.739 --> 00:03:51.900
# can see that its port 80 is open now
#
# 00:03:51.900 --> 00:03:53.400
# this is a case where I actually have
#
# 00:03:53.400 --> 00:03:56.669
# identified that my target is this exact
#
# 00:03:56.669 --> 00:03:58.409
# device here but you can use this
#
# 00:03:58.409 --> 00:03:59.939
# reconnaissance stage to find any other
#
# 00:03:59.939 --> 00:04:02.519
# port 80 device which has an open port 80
#
# 00:04:02.519 --> 00:04:04.919
# on your local network so now that we
#
# 00:04:04.919 --> 00:04:07.259
# used some network reconnaissance to
#
# 00:04:07.259 --> 00:04:09.209
# identify our target we're gonna go to
#
# 00:04:09.209 --> 00:04:10.469
# the next stage which is vulnerability
#
# 00:04:10.469 --> 00:04:12.449
# assessment so to do that we're gonna use
#
# 00:04:12.449 --> 00:04:14.699
# a tool called nassos which has been
#
# 00:04:14.699 --> 00:04:16.769
# covered on NOAA bite before and that
#
# 00:04:16.769 --> 00:04:18.209
# article will be links in the description
#
# 00:04:18.209 --> 00:04:19.709
# as well so this is gonna be assuming
#
# 00:04:19.709 --> 00:04:21.060
# that you have necess already up and
#
# 00:04:21.060 --> 00:04:23.430
# running on a computer so to navigate to
#
# 00:04:23.430 --> 00:04:25.680
# nessus you just have to open a web
#
# 00:04:25.680 --> 00:04:26.550
# browser I'm using
#
# 00:04:26.550 --> 00:04:29.460
# phox another type of an HTTP colon
#
# 00:04:29.460 --> 00:04:31.440
# forward slash forward slash localhost
#
# 00:04:31.440 --> 00:04:34.139
# and then you know specified port 88 30
#
# 00:04:34.139 --> 00:04:36.300
# for your web browser might notify you
#
# 00:04:36.300 --> 00:04:37.889
# that it could be a security risk to
#
# 00:04:37.889 --> 00:04:39.870
# navigate to that address but you're just
#
# 00:04:39.870 --> 00:04:41.610
# gonna let it know it's okay and once
#
# 00:04:41.610 --> 00:04:43.020
# you're here the first time using estus
#
# 00:04:43.020 --> 00:04:44.069
# you're gonna have to set up an account I
#
# 00:04:44.069 --> 00:04:45.419
# already have so I'm going to log in
#
# 00:04:45.419 --> 00:04:49.349
# under Koufax and then once you open the
#
# 00:04:49.349 --> 00:04:50.970
# necess the main screen is all the
#
# 00:04:50.970 --> 00:04:52.349
# different scans that you've saved or
#
# 00:04:52.349 --> 00:04:54.150
# have used previously on Nessus I've
#
# 00:04:54.150 --> 00:04:55.229
# already done the scan because it can
#
# 00:04:55.229 --> 00:04:56.250
# take a while but I'll just show you
#
# 00:04:56.250 --> 00:04:57.990
# exactly how I set it up so you just
#
# 00:04:57.990 --> 00:05:00.150
# press this new scan button and then
#
# 00:05:00.150 --> 00:05:02.610
# we're gonna do a basic local network
#
# 00:05:02.610 --> 00:05:05.250
# scan we're gonna call it null byte test
#
# 00:05:05.250 --> 00:05:09.330
# this is for the video tutorial and we're
#
# 00:05:09.330 --> 00:05:10.740
# just gonna save it in the default folder
#
# 00:05:10.740 --> 00:05:14.430
# and you could specify the target that we
#
# 00:05:14.430 --> 00:05:17.729
# identified which is 1.1 4 6 or you can
#
# 00:05:17.729 --> 00:05:19.500
# also do it like we did an nmap just
#
# 00:05:19.500 --> 00:05:20.940
# leave it at 1 and then specify the
#
# 00:05:20.940 --> 00:05:23.610
# subnet mask 24 and this will basically
#
# 00:05:23.610 --> 00:05:26.550
# leave these first three alone and then
#
# 00:05:26.550 --> 00:05:28.889
# just cycle through that last number on
#
# 00:05:28.889 --> 00:05:30.960
# our IP so additionally but like that I'm
#
# 00:05:30.960 --> 00:05:32.880
# gonna save it and then you'll see the
#
# 00:05:32.880 --> 00:05:35.009
# snow bite test and we can run it because
#
# 00:05:35.009 --> 00:05:36.449
# it's never been run before so you can
#
# 00:05:36.449 --> 00:05:38.009
# launch it and because this is a pretty
#
# 00:05:38.009 --> 00:05:40.289
# big scan it will take a while so before
#
# 00:05:40.289 --> 00:05:42.750
# I started recording I ran the scan
#
# 00:05:42.750 --> 00:05:45.270
# earlier and as you can see my Metasploit
#
# 00:05:45.270 --> 00:05:47.610
# able virtual machine has taking up a lot
#
# 00:05:47.610 --> 00:05:49.139
# of owner abilities and there's some
#
# 00:05:49.139 --> 00:05:50.430
# other devices I want to network which
#
# 00:05:50.430 --> 00:05:52.139
# might be susceptible to some
#
# 00:05:52.139 --> 00:05:54.330
# vulnerabilities as well so I'm gonna go
#
# 00:05:54.330 --> 00:05:55.949
# ahead and see what this is vulnerable to
#
# 00:05:55.949 --> 00:05:58.409
# as you can see it's using SSL so there's
#
# 00:05:58.409 --> 00:06:00.389
# some issues with SSL which is usually
#
# 00:06:00.389 --> 00:06:02.490
# associated with port 80 and so we know
#
# 00:06:02.490 --> 00:06:04.620
# that if we navigate to the web app then
#
# 00:06:04.620 --> 00:06:06.419
# it's probably gonna be a vulnerability
#
# 00:06:06.419 --> 00:06:08.190
# their command injection might be
#
# 00:06:08.190 --> 00:06:10.139
# possible so once you've identified that
#
# 00:06:10.139 --> 00:06:12.150
# yes this target that I'm interested in
#
# 00:06:12.150 --> 00:06:14.610
# is very vulnerable you can carry on to
#
# 00:06:14.610 --> 00:06:16.169
# the fourth step of the penetration test
#
# 00:06:16.169 --> 00:06:18.509
# which is the actual exploit the exciting
#
# 00:06:18.509 --> 00:06:18.870
# part
#
# 00:06:18.870 --> 00:06:21.360
# so my demonstration for a exploit is
#
# 00:06:21.360 --> 00:06:22.500
# just going to be a simple command
#
# 00:06:22.500 --> 00:06:25.199
# injection and so this is a part of
#
# 00:06:25.199 --> 00:06:27.120
# Metasploit level twos framework which is
#
# 00:06:27.120 --> 00:06:28.770
# the dam owner but web app but this could
#
# 00:06:28.770 --> 00:06:30.750
# be a substitute for any web app it's
#
# 00:06:30.750 --> 00:06:32.099
# just this is just for demonstration
#
# 00:06:32.099 --> 00:06:34.560
# purposes so if for some reason a web app
#
# 00:06:34.560 --> 00:06:37.469
# allows you to ping IP addresses then you
#
# 00:06:37.469 --> 00:06:39.169
# can take advantage of that
#
# 00:06:39.169 --> 00:06:40.879
# and use the computer that you're using
#
# 00:06:40.879 --> 00:06:43.249
# to ping and use it for whatever you want
#
# 00:06:43.249 --> 00:06:44.870
# to do in this case I'm gonna create a
#
# 00:06:44.870 --> 00:06:46.669
# reverse shelf so I can just do a simple
#
# 00:06:46.669 --> 00:06:49.150
# scan of the local host which is
#
# 00:06:49.150 --> 00:06:52.759
# 127.0.0.1 and if I submit that they'll
#
# 00:06:52.759 --> 00:06:54.710
# give me some information back now if I
#
# 00:06:54.710 --> 00:06:57.139
# specify this remote host and do an LS
#
# 00:06:57.139 --> 00:06:59.389
# command I'm not actually on this
#
# 00:06:59.389 --> 00:07:00.860
# computer I haven't logged into this
#
# 00:07:00.860 --> 00:07:02.930
# computer at all but I'm able to actually
#
# 00:07:02.930 --> 00:07:05.300
# see the files on this Metasploit able
#
# 00:07:05.300 --> 00:07:06.919
# computer without having to put a
#
# 00:07:06.919 --> 00:07:09.020
# password in or anything so because this
#
# 00:07:09.020 --> 00:07:10.550
# is not the best way to interact with
#
# 00:07:10.550 --> 00:07:12.020
# that computer let's go ahead and create
#
# 00:07:12.020 --> 00:07:13.999
# a netcat River shell now to do that
#
# 00:07:13.999 --> 00:07:15.080
# you're gonna have to open up your
#
# 00:07:15.080 --> 00:07:18.439
# terminal again and we're gonna create a
#
# 00:07:18.439 --> 00:07:21.259
# listening shell on our local computer so
#
# 00:07:21.259 --> 00:07:22.879
# to do that you just type in NC for
#
# 00:07:22.879 --> 00:07:25.039
# netcat tak l for listening and the port
#
# 00:07:25.039 --> 00:07:26.330
# you want to listen on I'm going to do
#
# 00:07:26.330 --> 00:07:28.460
# one two three four so now it's not gonna
#
# 00:07:28.460 --> 00:07:30.110
# give you any feedback it's just already
#
# 00:07:30.110 --> 00:07:32.300
# running the second you do that so now
#
# 00:07:32.300 --> 00:07:34.629
# we're gonna specify a local host and
#
# 00:07:34.629 --> 00:07:37.939
# then we're gonna do I typed in the
#
# 00:07:37.939 --> 00:07:39.229
# command earlier as you can see the test
#
# 00:07:39.229 --> 00:07:41.150
# but you're gonna type in and cat and
#
# 00:07:41.150 --> 00:07:43.819
# then you're gonna specify the IP address
#
# 00:07:43.819 --> 00:07:45.680
# of your local computer where you're
#
# 00:07:45.680 --> 00:07:47.569
# sending this to so I already know that
#
# 00:07:47.569 --> 00:07:52.669
# IP is 192.168.1.1 and they're gonna
#
# 00:07:52.669 --> 00:07:55.399
# specify the port which is one two three
#
# 00:07:55.399 --> 00:07:56.719
# four and then we're going to specify
#
# 00:07:56.719 --> 00:07:58.969
# tacky for execute and we're going to
#
# 00:07:58.969 --> 00:08:01.580
# create a terminal in the net cat shell
#
# 00:08:01.580 --> 00:08:03.050
# so you can go ahead and submit that it
#
# 00:08:03.050 --> 00:08:04.759
# might take a second or two and then now
#
# 00:08:04.759 --> 00:08:06.560
# if we go back to our terminal you can
#
# 00:08:06.560 --> 00:08:08.539
# see some funky stuff happen and actually
#
# 00:08:08.539 --> 00:08:09.169
# closed
#
# 00:08:09.169 --> 00:08:11.990
# so let's actually try that again oops
#
# 00:08:11.990 --> 00:08:14.779
# not clear I'm gonna try listening again
#
# 00:08:14.779 --> 00:08:16.879
# and then we're gonna do one two seven
#
# 00:08:16.879 --> 00:08:21.199
# one six eight two four three yeah that
#
# 00:08:21.199 --> 00:08:25.490
# all looks right and if you type in it's
#
# 00:08:25.490 --> 00:08:28.129
# still loading so now if you do Who am I
#
# 00:08:28.129 --> 00:08:31.879
# you get this www data and if we do LS
#
# 00:08:31.879 --> 00:08:33.620
# here we can see that these are the files
#
# 00:08:33.620 --> 00:08:36.079
# actually on the Metasploit able computer
#
# 00:08:36.079 --> 00:08:38.089
# and now we basically have a complete
#
# 00:08:38.089 --> 00:08:41.149
# shell so we can ping from here now and
#
# 00:08:41.149 --> 00:08:42.769
# you can see it's getting this data and
#
# 00:08:42.769 --> 00:08:44.300
# then actually enclosed it but from here
#
# 00:08:44.300 --> 00:08:46.220
# you can move on to the post exploitation
#
# 00:08:46.220 --> 00:08:48.890
# phase of the attack I'm going to be
#
# 00:08:48.890 --> 00:08:50.870
# using a previous video within on a tool
#
# 00:08:50.870 --> 00:08:52.399
# called posting um which you can use to
#
# 00:08:52.399 --> 00:08:53.060
# scan all
#
# 00:08:53.060 --> 00:08:55.130
# device and find any vulnerabilities that
#
# 00:08:55.130 --> 00:08:57.230
# that device is susceptible to so you can
#
# 00:08:57.230 --> 00:08:59.000
# either raise your privileges or create a
#
# 00:08:59.000 --> 00:09:01.790
# permanent backdoor into that computer so
#
# 00:09:01.790 --> 00:09:03.020
# assuming that you've been able to access
#
# 00:09:03.020 --> 00:09:05.480
# a the target computer either by creating
#
# 00:09:05.480 --> 00:09:06.920
# a reverse show with command injection or
#
# 00:09:06.920 --> 00:09:09.020
# whatsoever we can go ahead and install
#
# 00:09:09.020 --> 00:09:10.820
# posting them onto the target computer
#
# 00:09:10.820 --> 00:09:12.440
# but first let's download it onto our
#
# 00:09:12.440 --> 00:09:14.750
# computer first I just for reference this
#
# 00:09:14.750 --> 00:09:16.730
# left's black and green terminal is going
#
# 00:09:16.730 --> 00:09:18.680
# to be representing my local computer and
#
# 00:09:18.680 --> 00:09:20.810
# this blue and white terminal on the
#
# 00:09:20.810 --> 00:09:22.610
# right hand side is going to be
#
# 00:09:22.610 --> 00:09:24.230
# representing the targets computer this
#
# 00:09:24.230 --> 00:09:26.540
# is my reversal into that computer so if
#
# 00:09:26.540 --> 00:09:27.800
# you go ahead and navigate to the node by
#
# 00:09:27.800 --> 00:09:31.310
# article for posting them and you can if
#
# 00:09:31.310 --> 00:09:33.110
# you scroll up to one of the first steps
#
# 00:09:33.110 --> 00:09:36.410
# actually we can download posting them by
#
# 00:09:36.410 --> 00:09:38.000
# using the stub you get command just
#
# 00:09:38.000 --> 00:09:39.620
# downloading the script directly and
#
# 00:09:39.620 --> 00:09:41.570
# we're going to go ahead and install it
#
# 00:09:41.570 --> 00:09:45.560
# onto our local machine okay and then now
#
# 00:09:45.560 --> 00:09:48.950
# we can see that we have posting them
#
# 00:09:48.950 --> 00:09:50.779
# somewhere there that's the posting them
#
# 00:09:50.779 --> 00:09:53.589
# that SH and let's go ahead and set up a
#
# 00:09:53.589 --> 00:10:00.320
# simple HTTP server on port 1 2 3 4 ok
#
# 00:10:00.320 --> 00:10:01.940
# and then now if we go to our target
#
# 00:10:01.940 --> 00:10:05.180
# computer and now we can grab the posting
#
# 00:10:05.180 --> 00:10:10.280
# of that SH from our local machine oops
#
# 00:10:10.280 --> 00:10:12.440
# and you got to specify the port of
#
# 00:10:12.440 --> 00:10:15.200
# course there we go now if we look on
#
# 00:10:15.200 --> 00:10:16.850
# this local machine we have posts in them
#
# 00:10:16.850 --> 00:10:19.460
# so we can go ahead and try to route of
#
# 00:10:19.460 --> 00:10:20.600
# posting them like we would have normal
#
# 00:10:20.600 --> 00:10:22.520
# bash script but more often than that
#
# 00:10:22.520 --> 00:10:23.780
# it's not gonna work because it doesn't
#
# 00:10:23.780 --> 00:10:25.310
# have execute privileges so to do that
#
# 00:10:25.310 --> 00:10:27.920
# you just have to use chmod ok even
#
# 00:10:27.920 --> 00:10:29.089
# though we can go ahead and try and run
#
# 00:10:29.089 --> 00:10:31.490
# it like we did earlier when we go ahead
#
# 00:10:31.490 --> 00:10:33.530
# and make this bigger and as we can see
#
# 00:10:33.530 --> 00:10:37.459
# posting them is working now so let's go
#
# 00:10:37.459 --> 00:10:39.890
# ahead and I'll show off a couple
#
# 00:10:39.890 --> 00:10:41.540
# features so first we can see what
#
# 00:10:41.540 --> 00:10:43.100
# versions of software are actually
#
# 00:10:43.100 --> 00:10:44.959
# installed on this computer so we can see
#
# 00:10:44.959 --> 00:10:46.400
# if there's any outdated versions which
#
# 00:10:46.400 --> 00:10:48.220
# can be exploited to escalate privileges
#
# 00:10:48.220 --> 00:10:50.480
# so to do that all you have to do is run
#
# 00:10:50.480 --> 00:10:53.570
# posting them tak v oops
#
# 00:10:53.570 --> 00:10:56.480
# Sh
#
# 00:10:56.480 --> 00:11:01.190
# we can see versions for MySQL Apache
#
# 00:11:01.190 --> 00:11:03.260
# Java and we can see if any of these are
#
# 00:11:03.260 --> 00:11:07.550
# old outdated and we Vaughn herbal for
#
# 00:11:07.550 --> 00:11:10.160
# exploitation and 2020 or whatever year
#
# 00:11:10.160 --> 00:11:13.370
# you're doing this in and then one more
#
# 00:11:13.370 --> 00:11:15.079
# thing we can do is we can see what
#
# 00:11:15.079 --> 00:11:16.699
# development tools are available to us on
#
# 00:11:16.699 --> 00:11:18.800
# this computer whether PHP is installed
#
# 00:11:18.800 --> 00:11:21.050
# on this with a Perl or Python so we can
#
# 00:11:21.050 --> 00:11:22.250
# know what kind of scripts can actually
#
# 00:11:22.250 --> 00:11:25.089
# be applied to this configure OOP and
#
# 00:11:25.089 --> 00:11:26.870
# it's a
#
# 00:11:26.870 --> 00:11:29.870
# bash file and so we got some interesting
#
# 00:11:29.870 --> 00:11:31.850
# information we can see that Python Perl
#
# 00:11:31.850 --> 00:11:36.620
# PHP GCC which is a C++ compiler C C
#
# 00:11:36.620 --> 00:11:38.779
# which is a C compiler and nmap are all
#
# 00:11:38.779 --> 00:11:40.699
# installed on this computer so if we have
#
# 00:11:40.699 --> 00:11:42.440
# a Python script that we are ready to
#
# 00:11:42.440 --> 00:11:44.180
# deploy that will you know is pretty
#
# 00:11:44.180 --> 00:11:46.040
# effective at escalating user privileges
#
# 00:11:46.040 --> 00:11:48.769
# then we know that's we will be able to
#
# 00:11:48.769 --> 00:11:50.149
# deploy on to this computer
#
# 00:11:50.149 --> 00:11:52.339
# see how files can be uploaded we can use
#
# 00:11:52.339 --> 00:11:55.339
# FTP netcat W get which is what we use to
#
# 00:11:55.339 --> 00:11:57.139
# actually get posted them onto this
#
# 00:11:57.139 --> 00:11:59.060
# computer curl that's all that is
#
# 00:11:59.060 --> 00:12:02.149
# available to us and we can see what type
#
# 00:12:02.149 --> 00:12:04.190
# of shell terminal tools are available to
#
# 00:12:04.190 --> 00:12:07.190
# us so VI and them are installed and map
#
# 00:12:07.190 --> 00:12:09.050
# is installed Ruby which wasn't specified
#
# 00:12:09.050 --> 00:12:12.050
# earlier and we can see where all of
#
# 00:12:12.050 --> 00:12:14.449
# these environment variables are actually
#
# 00:12:14.449 --> 00:12:16.190
# installed in case one mess with that and
#
# 00:12:16.190 --> 00:12:18.440
# yeah so that's just the basics of things
#
# 00:12:18.440 --> 00:12:19.880
# you can do with posting them to escalate
#
# 00:12:19.880 --> 00:12:21.680
# your privileges in the post exploitation
#
# 00:12:21.680 --> 00:12:24.980
# stage of a penetration test if you liked
#
# 00:12:24.980 --> 00:12:26.779
# this tutorial be sure to check out our
#
# 00:12:26.779 --> 00:12:28.550
# website where we have hundreds of free
#
# 00:12:28.550 --> 00:12:30.410
# articles and videos as well as premium
#
# 00:12:30.410 --> 00:12:32.089
# paid content like the ethical hacking
#
# 00:12:32.089 --> 00:12:34.459
# certification bundle which features pen
#
# 00:12:34.459 --> 00:12:36.589
# testing with a Waze app WordPress
#
# 00:12:36.589 --> 00:12:38.480
# hacking and hardening and the comte a
#
# 00:12:38.480 --> 00:12:40.940
# cybersecurity analyst prep course check
#
# 00:12:40.940 --> 00:12:42.430
# out the link in the description below
#
# 00:12:42.430 --> 00:12:44.630
# well performing all of these steps to
#
# 00:12:44.630 --> 00:12:46.100
# completion may seem a little overzealous
#
# 00:12:46.100 --> 00:12:48.649
# for any complicated tasks such as pen
#
# 00:12:48.649 --> 00:12:50.089
# testing it's important to have a proven
#
# 00:12:50.089 --> 00:12:51.949
# set of steps that you can fall back on a
#
# 00:12:51.949 --> 00:12:54.260
# case things go awry and I should remind
#
# 00:12:54.260 --> 00:12:55.670
# you that what we showed off today was
#
# 00:12:55.670 --> 00:12:57.620
# just one demonstration of these six
#
# 00:12:57.620 --> 00:12:59.720
# steps your experience with these six
#
# 00:12:59.720 --> 00:13:01.730
# section a very widely based on the type
#
# 00:13:01.730 --> 00:13:03.260
# of device that you're targeting or the
#
# 00:13:03.260 --> 00:13:04.550
# type of vulnerability that you're trying
#
# 00:13:04.550 --> 00:13:06.740
# to exploit again if you have any
#
# 00:13:06.740 --> 00:13:07.970
# problems following this video tutorial
#
# 00:13:07.970 --> 00:13:09.690
# you can check out the article
#
# 00:13:09.690 --> 00:13:11.730
# in the description if you have any ideas
#
# 00:13:11.730 --> 00:13:13.530
# for a future video hit me up at Twitter
#
# 00:13:13.530 --> 00:13:15.420
# at Nik Kershaw thank you guys for
#
# 00:13:15.420 --> 00:13:18.560
# watching and I'll see you next time
